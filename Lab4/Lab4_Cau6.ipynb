# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

# %%
data = pd.read_csv('C:\\Users\\84346\\Desktop\\Data\\mushrooms.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
#Chuyển đổi dữ liệu thành số
temp = {"e":1,"p":2}
for dataset in [data]:
    dataset['class']=dataset['class'].map(temp)

# %%
#Chuyển đổi dữ liệu thành số
temp = {"x":1,"f":2,"k":3,"b":4,"s":5,"c":6}
for dataset in [data]:
    dataset['cap-shape']=dataset['cap-shape'].map(temp)

# %%
#Chuyển đổi dữ liệu thành số
temp = {"y":1,"s":2,"f":3,"g":4}
for dataset in [data]:
    dataset['cap-surface']=dataset['cap-surface'].map(temp)

# %%
#Chuyển đổi dữ liệu thành số
temp = {"n":1,"g":2,"e":3,"y":4,"w":5,"b":6,"p":7,"c":8,"r":9,"u":10}
for dataset in [data]:
    dataset['cap-color']=dataset['cap-color'].map(temp)

# %%
#Chuyển đổi dữ liệu thành số
temp = {"f":1,"t":2}
for dataset in [data]:
    dataset['bruises']=dataset['bruises'].map(temp)

# %%
#Chuyển đổi dữ liệu thành số
temp = {"n":1,"f":2,"y":3,"s":4,"l":5,"a":6,"p":7,"c":8,"m":9}
for dataset in [data]:
    dataset['odor']=dataset['odor'].map(temp)

# %%
#Chuyển đổi dữ liệu thành số
temp = {"f":1,"a":2}
for dataset in [data]:
    dataset['gill-attachment']=dataset['gill-attachment'].map(temp)

# %%
#Chuyển đổi dữ liệu thành số
temp = {"c":1,"w":2}
for dataset in [data]:
    dataset['gill-spacing']=dataset['gill-spacing'].map(temp)

# %%
#Chuyển đổi dữ liệu thành số
temp = {"b":1,"n":2}
for dataset in [data]:
    dataset['gill-size']=dataset['gill-size'].map(temp)

# %%
#Chuyển đổi dữ liệu thành số
temp = {"b":1,"p":2,"w":3,"n":4,"g":5,"h":6,"u":7,"k":8,"e":9,"y":10,"o":11,"r":12}
for dataset in [data]:
    dataset['gill-color']=dataset['gill-color'].map(temp)

# %%
#Chuyển đổi dữ liệu thành số
temp = {"t":1,"e":2}
for dataset in [data]:
    dataset['stalk-shape']=dataset['stalk-shape'].map(temp)

# %%
#Chuyển đổi dữ liệu thành số
temp = {"b":1,"?":2,"e":3,"c":4,"r":5}
for dataset in [data]:
    dataset['stalk-root']=dataset['stalk-root'].map(temp)

# %%
#Chuyển đổi dữ liệu thành số
temp = {"s":1,"k":2,"f":3,"y":4}
for dataset in [data]:
    dataset['stalk-surface-above-ring']=dataset['stalk-surface-above-ring'].map(temp)

# %%
#Chuyển đổi dữ liệu thành số
temp = {"s":1,"k":2,"f":3,"y":4}
for dataset in [data]:
    dataset['stalk-surface-below-ring']=dataset['stalk-surface-below-ring'].map(temp)

# %%
#Chuyển đổi dữ liệu thành số
temp = {"w":1,"p":2,"g":3,"n":4,"b":5,"o":6,"e":7,"c":8,"y":9}
for dataset in [data]:
    dataset['stalk-color-above-ring']=dataset['stalk-color-above-ring'].map(temp)

# %%
#Chuyển đổi dữ liệu thành số
temp = {"w":1,"p":2,"g":3,"n":4,"b":5,"o":6,"e":7,"c":8,"y":9}
for dataset in [data]:
    dataset['stalk-color-below-ring']=dataset['stalk-color-below-ring'].map(temp)

# %%
#Chuyển đổi dữ liệu thành số
temp = {"p":1}
for dataset in [data]:
    dataset['veil-type']=dataset['veil-type'].map(temp)

# %%
#Chuyển đổi dữ liệu thành số
temp = {"w":1,"o":2,"n":3,"y":4}
for dataset in [data]:
    dataset['veil-color']=dataset['veil-color'].map(temp)

# %%
#Chuyển đổi dữ liệu thành số
temp = {"o":1,"t":2,"n":3}
for dataset in [data]:
    dataset['ring-number']=dataset['ring-number'].map(temp)

# %%
#Chuyển đổi dữ liệu thành số
temp = {"p":1,"e":2,"l":3,"f":4,"n":5}
for dataset in [data]:
    dataset['ring-type']=dataset['ring-type'].map(temp)

# %%
#Chuyển đổi dữ liệu thành số
temp = {"w":1,"n":2,"k":3,"h":4,"r":5,"b":6,"u":7,"y":8,"o":9}
for dataset in [data]:
    dataset['spore-print-color']=dataset['spore-print-color'].map(temp)

# %%
#Chuyển đổi dữ liệu thành số
temp = {"v":1,"y":2,"s":3,"n":4,"a":5,"c":6}
for dataset in [data]:
    dataset['population']=dataset['population'].map(temp)

# %%
#Chuyển đổi dữ liệu thành số
temp = {"d":1,"g":2,"p":3,"l":4,"u":5,"m":6,"w":7}
for dataset in [data]:
    dataset['habitat']=dataset['habitat'].map(temp)

# %%
plt.figure(figsize=(16,9))
sns.heatmap(data.corr(method='pearson'),annot=True)
# Out:
# <AxesSubplot:>

# %%
data
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  gill-spacing  \
# 0         2          1            2          1        2             1
# 1         1          1            2          4        2             1
# 2         1          4            2          5        2             1
# 3         2          1            1          5        2             1
# 4         1          1            2          2        1             2
# ...     ...        ...          ...        ...      ...           ...
# 8119      1          3            2          1        1             1
# 8120      1          1            2          1        1             1
# 8121      1          2            2          1        1             1
# 8122      2          3            1          1        1             1
# 8123      1          1            2          1        1             1
#
#       veil-color  ring-number  habitat
# 0              1            1        5
# 1              1            1        2
# ...

# %%
features = data.drop('class',axis=1)
labels = data['class']

# %%
X_train,X_test,y_train,y_test = train_test_split(features, labels, test_size=0.3, random_state=42)

# %%
clf = tree.DecisionTreeClassifier(criterion="entropy",random_state=0)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
tree_pred = clf.predict(X_test)

tree_score = metrics.accuracy_score(y_test, tree_pred)
print("Accuracy",tree_score)
print("Report", metrics.classification_report(y_test, tree_pred))
# Out:
# Accuracy 0.9885151763740772
# Report               precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99      1257
#            2       0.99      0.98      0.99      1181
#
#     accuracy                           0.99      2438
#    macro avg       0.99      0.99      0.99      2438
# weighted avg       0.99      0.99      0.99      2438

# %%
tree_cm = metrics.confusion_matrix(y_test,tree_pred)
tree_cm
# Out:
# array([[1248,    9],
#        [  19, 1162]], dtype=int64)

# %%
plt.figure(figsize=(12,12))
sns.heatmap(tree_cm, annot=True, fmt=".3f",linewidths=.5, square=True,cmap='Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
title = 'Decision Tree Accuracy Score: {0}'.format(tree_score)
plt.title(title,size=15);
plt.show()

# %%
#Biểu diễn cây ID3 
fig,ax = plt.subplots(figsize=(50,24))
tree.plot_tree(clf,filled=True,fontsize=10)
plt.savefig('decision_tree',dpi=100)
plt.show()

# %%
#Xây dựng cây CART
clf2= tree.DecisionTreeClassifier(criterion="gini", random_state=0)
clf2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
tree_pred2 = clf2.predict(X_test)

tree_score2 = metrics.accuracy_score(y_test,tree_pred2)

sk_report = metrics.classification_report(y_test, tree_pred2)

print("Accuracy",tree_score2)
print("Report",sk_report)
# Out:
# Accuracy 0.9885151763740772
# Report               precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99      1257
#            2       0.99      0.98      0.99      1181
#
#     accuracy                           0.99      2438
#    macro avg       0.99      0.99      0.99      2438
# weighted avg       0.99      0.99      0.99      2438

# %%
#Ma trận nhầm lẫn
tree_cm2 = metrics.confusion_matrix(y_test,tree_pred2)
tree_cm2
# Out:
# array([[1248,    9],
#        [  19, 1162]], dtype=int64)

# %%
#Biểu diễn ma trận nhầm lẫn lên đồ thị heatmap
plt.figure(figsize=(12,12))
sns.heatmap(tree_cm2, annot=True, fmt=".3f",linewidths=.5, square=True,cmap='Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
title = 'Decision Tree Accuracy Score: {0}'.format(tree_score)
plt.title(title,size=15);
plt.show()

# %%
#Biểu diễn cây gini 
fig,ax = plt.subplots(figsize=(50,24))
tree.plot_tree(clf2,filled=True,fontsize=10)
plt.savefig('decision_tree',dpi=100)
plt.show()

# %%
#Thuật toán Naïve Bayes
gnb = GaussianNB()
bayes_pred = gnb.fit(X_train, y_train).predict(X_test)

# %%
bayes_score = metrics.accuracy_score(y_test,bayes_pred)
print("Accuracy: ",bayes_score)
print("Report: ", metrics.classification_report(y_test, bayes_pred))
# Out:
# Accuracy:  0.7957342083675144
# Report:                precision    recall  f1-score   support
#
#            1       0.89      0.69      0.78      1257
#            2       0.73      0.91      0.81      1181
#
#     accuracy                           0.80      2438
#    macro avg       0.81      0.80      0.79      2438
# weighted avg       0.81      0.80      0.79      2438

# %%
bayes_cm = metrics.confusion_matrix(y_test,bayes_pred)

#Biểu diễn ma trận nhầm lẫn lên đồ thị heatmap
plt.figure(figsize=(12,12))
sns.heatmap(bayes_cm, annot=True, fmt=".3f",linewidths=.5,square=True,cmap="Greens");
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
title = 'Naive Bayes Accuracy Score: {0}'.format(bayes_score)
plt.title(title,size=15);
plt.show()

# %% [markdown]
# # Ta có thể kết luận được mô hình được xây dựng bởi thuật toán Naïve Bayes có độ chính xác cao hơn mô hình cây quyết định theo thuật toán CART.
